# %%
import pandas as pd
import pyodbc as py
connection_string = (    
    r'Driver={SQL Server};'
    r'Server=LAPTOP-LD74USH0\SQLEXPRESS;'
    r'Integrated Security=SSPI;'
    r'Trusted_Connection=yes;'
)
pd.set_option('display.max_columns', None)

# %%
import seaborn as sns
from datetime import date

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
def sql2df(query, params=[], parse_dates=None, dsn='SQLEXPRESS'):
        with py.connect(connection_string, readonly=True) as conn:
            return pd.read_sql(query, conn, params=params, parse_dates=parse_dates)

# %%
df = sql2df('''
SELECT * FROM Seminar.dbo.cleaned_bol_data_full;
''')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4772950 entries, 0 to 4772949
# Data columns (total 78 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   orderDate                         object
#  1   productId                         object
#  2   sellerId                          object
#  3   totalPrice                        float64
#  4   quantityOrdered                   int64
#  5   countryCode                       object
#  6   cancellationDate                  object
#  7   cancellationReasonCode            object
#  8   promisedDeliveryDate              object
#  9   shipmentDate                      object
#  10  transporterCode                   object
#  11  transporterName                   object
#  12  transporterNameOther              object
#  13  dateTimeFirstDeliveryMoment       datetime64[ns]
#  14  fulfilmentType                    object
#  15  startDateCase                     object
#  16  cntDistinctCaseIds                float64
#  17  returnDateTime                    object
#  18  quantityReturned                  float64
#  19  returnCode                        object
#  20  productTitle                      object
#  21  brickName                         object
#  22  chunkName                         object
#  23  productGroup                      object
#  24  productSubGroup                   object
#  25  productSubSubGroup                object
#  26  registrationDateSeller            object
#  27  countryOriginSeller               object
#  28  currentCountryAvailabilitySeller  object
#  29  calculationDefinitive             bool
#  30  noCancellation                    bool
#  31  onTimeDelivery                    object
#  32  noCase                            bool
#  33  hasOneCase                        bool
#  34  hasMoreCases                      bool
#  35  noReturn                          bool
#  36  detailedMatchClassification       object
#  37  generalMatchClassification        object
#  38  determinantClassification         object
#  39  orderYear                         int64
#  40  orderMonth                        object
#  41  orderYearMonth                    object
#  42  orderWeekday                      int64
#  43  orderWeekend                      int64
#  44  orderCorona                       object
#  45  transporterFeature                object
#  46  partnerSellingMonths              int64
#  47  cancellationDays                  float64
#  48  shipmentDays                      float64
#  49  promisedDeliveryDays              int64
#  50  actualDeliveryDays                float64
#  51  caseDays                          float64
#  52  returnDays                        float64
#  53  countryCodeNL                     int64
#  54  fulfilmentByBol                   int64
#  55  countryOriginNL                   int64
#  56  countryOriginBE                   int64
#  57  countryOriginDE                   int64
#  58  orderMonday                       int64
#  59  orderTuesday                      int64
#  60  orderWednesday                    int64
#  61  orderThursday                     int64
#  62  orderFriday                       int64
#  63  orderSaturday                     int64
#  64  orderSunday                       int64
#  65  orderJanuary                      int64
#  66  orderFebruary                     int64
#  67  orderMarch                        int64
#  68  orderApril                        int64
#  69  orderMay                          int64
#  70  orderJune                         int64
#  71  orderJuly                         int64
#  72  orderAugust                       int64
#  73  orderSeptember                    int64
#  74  orderOctober                      int64
#  75  orderNovember                     int64
#  76  orderDecember                     int64
#  77  productTitleLength                int64
# dtypes: bool(6), datetime64[ns](1), float64(8), int64(31), object(32)
# memory usage: 2.6+ GB

# %%
#Change type of columns
dtype = {'calculationDefinitive': bool,
         'noCancellation': bool,
         'noCase': bool,
         'hasOneCase': bool,
         'hasMoreCases': bool,
         'noReturn': bool,
         'orderWeekend': bool,
         'orderCorona': bool,
         'countryCodeNL': bool,
         'fulfilmentByBol': bool,
         'countryOriginNL': bool,
         'countryOriginBE': bool,
         'countryOriginDE': bool,
         'orderMonday': bool,
         'orderTuesday': bool,
         'orderWednesday': bool,
         'orderThursday': bool,
         'orderFriday': bool,
         'orderSaturday': bool,
         'orderSunday': bool,
         'orderJanuary': bool,
         'orderFebruary': bool,
         'orderMarch': bool,
         'orderApril': bool,
         'orderMay': bool,
         'orderJune': bool,
         'orderJuly': bool,
         'orderAugust': bool,
         'orderSeptember': bool,
         'orderOctober': bool,
         'orderNovember': bool,
         'orderDecember': bool}

df = df.astype(dtype)

#Transform dates to date-type
df['orderDate'] = pd.to_datetime(df['orderDate'], errors='coerce')
df['cancellationDate'] = pd.to_datetime(df['cancellationDate'], errors='coerce')
df['promisedDeliveryDate'] = pd.to_datetime(df['promisedDeliveryDate'], errors='coerce')
df['shipmentDate'] = pd.to_datetime(df['shipmentDate'], errors='coerce')
df['dateTimeFirstDeliveryMoment'] = pd.to_datetime(df['dateTimeFirstDeliveryMoment'], errors='coerce')
df['startDateCase'] = pd.to_datetime(df['startDateCase'], errors='coerce')
df['returnDateTime'] = pd.to_datetime(df['returnDateTime'], errors='coerce')
df['registrationDateSeller'] = pd.to_datetime(df['registrationDateSeller'], errors='coerce')

df.dtypes
# Out:
# orderDate             datetime64[ns]
# productId                     object
# sellerId                      object
# totalPrice                   float64
# quantityOrdered                int64
#                            ...
# orderSeptember                  bool
# orderOctober                    bool
# orderNovember                   bool
# orderDecember                   bool
# productTitleLength             int64
# Length: 78, dtype: object

# %%
df.head()
# Out:
#    orderDate         productId sellerId  totalPrice  quantityOrdered  \
# 0 2019-12-06  9000000012387632   656525       53.00                1
# 1 2019-07-07  9200000011323565   656525       56.95                1
# 2 2019-11-25  9200000046125841   656525       16.95                1
# 3 2019-08-04  9200000086468758   656525       34.95                1
# 4 2019-04-12  1000004001422158   742787       14.99                1
#
#   countryCode cancellationDate cancellationReasonCode promisedDeliveryDate  \
# 0          NL              NaT                   None           2019-12-09
# 1          NL              NaT                   None           2019-07-09
# 2          NL              NaT                   None           2019-11-27
# 3          NL              NaT                   None           2019-08-06
# 4          NL              NaT                   None           2019-04-16
#
#   shipmentDate transporterCode   transporterName transporterNameOther  \
# 0   2019-12-06             UPS               UPS                 None
# 1   2019-07-08             UPS               UPS                 None
# 2   2019-11-26             UPS               UPS                 None
# 3   2019-08-05             UPS               UPS                 None
# 4   2019-04-13       TNT_BRIEF  PostNL Briefpost                 None
#
#   dateTimeFirstDeliveryMoment fulfilmentType startDateCase  \
# 0                         NaT            FBR           NaT
# 1                         NaT            FBR           NaT
# 2                         NaT            FBR           NaT
# 3                         NaT            FBR           NaT
# 4                         NaT            FBR           NaT
#
#    cntDistinctCaseIds returnDateTime  quantityReturned returnCode  \
# 0                 NaN            NaT               NaN       None
# 1                 NaN            NaT               NaN       None
# 2                 NaN            NaT               NaN       None
# 3                 NaN            NaT               NaN       None
# 4                 NaN            NaT               NaN       None
#
#                                         productTitle            brickName  \
# 0  Bresser Optics Hunter 16 x 50 verrekijker BK-7...         Verrekijkers
# 1        National Geographic Verrekijker 10x50 Porro         Verrekijkers
# 2  National Geographic 4x30 BK-7 Zwart, Geel verr...         Verrekijkers
# 3  Bresser Microscoop preparaten 25 stuks - Biologie         Verrekijkers
# 4                        The Very Best of the Eagles  Voorbespeelde Audio
#
#      chunkName                   productGroup              productSubGroup  \
# 0  Verrekijker   Sound and Vision Accessories  Beeld en Geluid Accessoires
# 1  Verrekijker   Sound and Vision Accessories  Beeld en Geluid Accessoires
# 2  Verrekijker   Sound and Vision Accessories  Beeld en Geluid Accessoires
# 3  Verrekijker  Recreational and Outdoor Toys      Leren en Experimenteren
# 4       Muziek                          Music                           CD
#
#         productSubSubGroup registrationDateSeller countryOriginSeller  \
# 0       Camera Accessoires             2012-07-04                  NL
# 1       Camera Accessoires             2012-07-04                  NL
# 2       Camera Accessoires             2012-07-04                  NL
# 3  Leren en Experimenteren             2012-07-04                  NL
# 4                       CD             2013-01-28                  NL
#
#   currentCountryAvailabilitySeller  calculationDefinitive  noCancellation  \
# 0                              ALL                   True            True
# 1                              ALL                   True            True
# 2                              ALL                   True            True
# 3                              ALL                   True            True
# 4                               NL                   True            True
#
#   onTimeDelivery  noCase  hasOneCase  hasMoreCases  noReturn  \
# 0           None    True       False         False      True
# 1           None    True       False         False      True
# 2           None    True       False         False      True
# 3           None    True       False         False      True
# 4           None    True       False         False      True
#
#   detailedMatchClassification generalMatchClassification  \
# 0                     UNKNOWN                    UNKNOWN
# 1                     UNKNOWN                    UNKNOWN
# 2                     UNKNOWN                    UNKNOWN
# 3                     UNKNOWN                    UNKNOWN
# 4                     UNKNOWN                    UNKNOWN
#
#   determinantClassification  orderYear orderMonth orderYearMonth  \
# 0          Unknown delivery       2019         12        2019-12
# 1          Unknown delivery       2019         07        2019-07
# 2          Unknown delivery       2019         11        2019-11
# 3          Unknown delivery       2019         08        2019-08
# 4          Unknown delivery       2019         04        2019-04
#
#    orderWeekday  orderWeekend  orderCorona transporterFeature  \
# 0             5         False         True                UPS
# 1             7          True         True                UPS
# 2             1         False         True                UPS
# 3             7          True         True                UPS
# 4             5         False         True          TNT_BRIEF
#
#    partnerSellingMonths  cancellationDays  shipmentDays  promisedDeliveryDays  \
# 0                    89               NaN           0.0                     3
# 1                    84               NaN           1.0                     2
# 2                    88               NaN           1.0                     2
# 3                    85               NaN           1.0                     2
# 4                    75               NaN           1.0                     4
#
#    actualDeliveryDays  caseDays  returnDays  countryCodeNL  fulfilmentByBol  \
# 0                 NaN       NaN         NaN           True            False
# 1                 NaN       NaN         NaN           True            False
# 2                 NaN       NaN         NaN           True            False
# 3                 NaN       NaN         NaN           True            False
# 4                 NaN       NaN         NaN           True            False
#
#    countryOriginNL  countryOriginBE  countryOriginDE  orderMonday  \
# 0             True            False            False        False
# 1             True            False            False        False
# 2             True            False            False         True
# 3             True            False            False        False
# 4             True            False            False        False
#
#    orderTuesday  orderWednesday  orderThursday  orderFriday  orderSaturday  \
# 0         False           False          False         True          False
# 1         False           False          False        False          False
# 2         False           False          False        False          False
# 3         False           False          False        False          False
# 4         False           False          False         True          False
#
#    orderSunday  orderJanuary  orderFebruary  orderMarch  orderApril  orderMay  \
# 0        False         False          False       False       False     False
# 1         True         False          False       False       False     False
# 2        False         False          False       False       False     False
# 3         True         False          False       False       False     False
# 4        False         False          False       False        True     False
#
#    orderJune  orderJuly  orderAugust  orderSeptember  orderOctober  \
# 0      False      False        False           False         False
# 1      False       True        False           False         False
# 2      False      False        False           False         False
# 3      False      False         True           False         False
# 4      False      False        False           False         False
#
#    orderNovember  orderDecember  productTitleLength
# 0          False           True                  52
# 1          False          False                  43
# 2           True          False                  53
# 3          False          False                  49
# 4          False          False                  27

# %%
df.describe(include = 'all', datetime_is_numeric = False)
# Out:
# <ipython-input-9-1283d777435d>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include = 'all', datetime_is_numeric = False)
# <ipython-input-9-1283d777435d>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include = 'all', datetime_is_numeric = False)
# <ipython-input-9-1283d777435d>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include = 'all', datetime_is_numeric = False)
# <ipython-input-9-1283d777435d>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include = 'all', datetime_is_numeric = False)
# <ipython-input-9-1283d777435d>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include = 'all', datetime_is_numeric = False)
# <ipython-input-9-1283d777435d>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include = 'all', datetime_is_numeric = False)
# <ipython-input-9-1283d777435d>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include = 'all', datetime_is_numeric = False)
# <ipython-input-9-1283d777435d>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include = 'all', datetime_is_numeric = False)
#                   orderDate         productId sellerId    totalPrice  \
# count               4772950           4772950  4772950  4.772950e+06
# unique                  716            428670     1911           NaN
# top     2020-12-14 00:00:00  9200000075472002   829931           NaN
# freq                  21860             47201   812624           NaN
# first   2019-01-01 00:00:00               NaN      NaN           NaN
# last    2020-12-16 00:00:00               NaN      NaN           NaN
# mean                    NaN               NaN      NaN  3.317557e+01
# std                     NaN               NaN      NaN  6.079791e+01
# min                     NaN               NaN      NaN  6.900000e-01
# 25%                     NaN               NaN      NaN  1.295000e+01
# 50%                     NaN               NaN      NaN  1.900000e+01
# 75%                     NaN               NaN      NaN  3.145000e+01
# max                     NaN               NaN      NaN  1.063720e+04
#
#         quantityOrdered countryCode     cancellationDate  \
# count      4.772950e+06     4772950                77473
# unique              NaN           2                  739
# top                 NaN          NL  2020-12-14 00:00:00
# freq                NaN     3554065                  394
# first               NaN         NaN  2019-01-01 00:00:00
# last                NaN         NaN  2021-01-11 00:00:00
# mean       1.110494e+00         NaN                  NaN
# std        8.254498e-01         NaN                  NaN
# min        1.000000e+00         NaN                  NaN
# 25%        1.000000e+00         NaN                  NaN
# 50%        1.000000e+00         NaN                  NaN
# 75%        1.000000e+00         NaN                  NaN
# max        3.000000e+02         NaN                  NaN
#
#        cancellationReasonCode promisedDeliveryDate         shipmentDate  \
# count                   77473              4772950              4695498
# unique                     25                  716                  737
# top                   CUST_FE  2020-12-01 00:00:00  2020-11-30 00:00:00
# freq                    50969                26237                27129
# first                     NaN  2019-01-02 00:00:00  2019-01-01 00:00:00
# last                      NaN  2021-01-06 00:00:00  2021-01-09 00:00:00
# mean                      NaN                  NaN                  NaN
# std                       NaN                  NaN                  NaN
# min                       NaN                  NaN                  NaN
# 25%                       NaN                  NaN                  NaN
# 50%                       NaN                  NaN                  NaN
# 75%                       NaN                  NaN                  NaN
# max                       NaN                  NaN                  NaN
#
#        transporterCode transporterName transporterNameOther  \
# count          4686467         4686467                56017
# unique              27              27                    2
# top                TNT          PostNL                OTHER
# freq           2108544         2108544                53494
# first              NaN             NaN                  NaN
# last               NaN             NaN                  NaN
# mean               NaN             NaN                  NaN
# std                NaN             NaN                  NaN
# min                NaN             NaN                  NaN
# 25%                NaN             NaN                  NaN
# 50%                NaN             NaN                  NaN
# 75%                NaN             NaN                  NaN
# max                NaN             NaN                  NaN
#
#        dateTimeFirstDeliveryMoment fulfilmentType        startDateCase  \
# count                      3067802        4772950               164358
# unique                     2612759              2                  745
# top            2020-12-12 00:00:00            FBR  2019-12-03 00:00:00
# freq                           170        3448479                 1101
# first          2019-01-02 13:00:33            NaN  2019-01-01 00:00:00
# last           2021-01-14 17:42:31            NaN  2021-01-14 00:00:00
# mean                           NaN            NaN                  NaN
# std                            NaN            NaN                  NaN
# min                            NaN            NaN                  NaN
# 25%                            NaN            NaN                  NaN
# 50%                            NaN            NaN                  NaN
# 75%                            NaN            NaN                  NaN
# max                            NaN            NaN                  NaN
#
#         cntDistinctCaseIds       returnDateTime  quantityReturned  \
# count        164358.000000               288763     284877.000000
# unique                 NaN                  744               NaN
# top                    NaN  2020-12-01 00:00:00               NaN
# freq                   NaN                  819               NaN
# first                  NaN  2019-01-02 00:00:00               NaN
# last                   NaN  2021-01-14 00:00:00               NaN
# mean              1.171528                  NaN          1.142816
# std               0.508393                  NaN          0.935651
# min               1.000000                  NaN          1.000000
# 25%               1.000000                  NaN          1.000000
# 50%               1.000000                  NaN          1.000000
# 75%               1.000000                  NaN          1.000000
# max              14.000000                  NaN        225.000000
#
#                 returnCode                                   productTitle  \
# count                 6554                                        4772950
# unique                  11                                         470954
# top     NO_REASON_PROVIDED  Apple EarPods - met lightning connector - wit
# freq                  2256                                          38613
# first                  NaN                                            NaN
# last                   NaN                                            NaN
# mean                   NaN                                            NaN
# std                    NaN                                            NaN
# min                    NaN                                            NaN
# 25%                    NaN                                            NaN
# 50%                    NaN                                            NaN
# 75%                    NaN                                            NaN
# max                    NaN                                            NaN
#
#                             brickName                     chunkName  \
# count                         4772950                       4753595
# unique                           1116                          4325
# top     Hoesjes voor Mobiele Telefoon  Hoesje voor mobiele telefoon
# freq                           497517                        426146
# first                             NaN                           NaN
# last                              NaN                           NaN
# mean                              NaN                           NaN
# std                               NaN                           NaN
# min                               NaN                           NaN
# 25%                               NaN                           NaN
# 50%                               NaN                           NaN
# 75%                               NaN                           NaN
# max                               NaN                           NaN
#
#                             productGroup                  productSubGroup  \
# count                            4772950                          4772950
# unique                                60                              444
# top     Telephone and Tablet Accessories  Telefonie en Tablet Bescherming
# freq                              847870                           565441
# first                                NaN                              NaN
# last                                 NaN                              NaN
# mean                                 NaN                              NaN
# std                                  NaN                              NaN
# min                                  NaN                              NaN
# 25%                                  NaN                              NaN
# 50%                                  NaN                              NaN
# 75%                                  NaN                              NaN
# max                                  NaN                              NaN
#
#            productSubSubGroup registrationDateSeller countryOriginSeller  \
# count                 4772950                4772950             4772950
# unique                    966                   1207                   3
# top     Telefonie Bescherming    2013-07-31 00:00:00                  NL
# freq                   494430                 812624             4678541
# first                     NaN    2007-04-27 00:00:00                 NaN
# last                      NaN    2020-11-01 00:00:00                 NaN
# mean                      NaN                    NaN                 NaN
# std                       NaN                    NaN                 NaN
# min                       NaN                    NaN                 NaN
# 25%                       NaN                    NaN                 NaN
# 50%                       NaN                    NaN                 NaN
# 75%                       NaN                    NaN                 NaN
# max                       NaN                    NaN                 NaN
#
#        currentCountryAvailabilitySeller calculationDefinitive noCancellation  \
# count                           4772950               4772950        4772950
# unique                                3                     1              2
# top                                  NL                  True           True
# freq                            3138478               4772950        4749257
# first                               NaN                   NaN            NaN
# last                                NaN                   NaN            NaN
# mean                                NaN                   NaN            NaN
# std                                 NaN                   NaN            NaN
# min                                 NaN                   NaN            NaN
# 25%                                 NaN                   NaN            NaN
# 50%                                 NaN                   NaN            NaN
# 75%                                 NaN                   NaN            NaN
# max                                 NaN                   NaN            NaN
#
#        onTimeDelivery   noCase hasOneCase hasMoreCases noReturn  \
# count         3063699  4772950    4772950      4772950  4772950
# unique              2        2          2            2        2
# top              true     True      False        False     True
# freq          2898055  4608592    4630323      4751219  4492395
# first             NaN      NaN        NaN          NaN      NaN
# last              NaN      NaN        NaN          NaN      NaN
# mean              NaN      NaN        NaN          NaN      NaN
# std               NaN      NaN        NaN          NaN      NaN
# min               NaN      NaN        NaN          NaN      NaN
# 25%               NaN      NaN        NaN          NaN      NaN
# 50%               NaN      NaN        NaN          NaN      NaN
# 75%               NaN      NaN        NaN          NaN      NaN
# max               NaN      NaN        NaN          NaN      NaN
#
#        detailedMatchClassification generalMatchClassification  \
# count                      4772950                    4772950
# unique                           5                          3
# top                    KNOWN HAPPY                KNOWN HAPPY
# freq                       2685606                    2685606
# first                          NaN                        NaN
# last                           NaN                        NaN
# mean                           NaN                        NaN
# std                            NaN                        NaN
# min                            NaN                        NaN
# 25%                            NaN                        NaN
# 50%                            NaN                        NaN
# 75%                            NaN                        NaN
# max                            NaN                        NaN
#
#        determinantClassification     orderYear orderMonth orderYearMonth  \
# count                    4772950  4.772950e+06    4772950        4772950
# unique                        14           NaN         12             24
# top                     All good           NaN         11        2020-11
# freq                     2685606           NaN     606765         381513
# first                        NaN           NaN        NaN            NaN
# last                         NaN           NaN        NaN            NaN
# mean                         NaN  2.019596e+03        NaN            NaN
# std                          NaN  4.906660e-01        NaN            NaN
# min                          NaN  2.019000e+03        NaN            NaN
# 25%                          NaN  2.019000e+03        NaN            NaN
# 50%                          NaN  2.020000e+03        NaN            NaN
# 75%                          NaN  2.020000e+03        NaN            NaN
# max                          NaN  2.020000e+03        NaN            NaN
#
#         orderWeekday orderWeekend orderCorona transporterFeature  \
# count   4.772950e+06      4772950     4772950            4772950
# unique           NaN            2           1                 24
# top              NaN        False        True                TNT
# freq             NaN      3564479     4772950            2108544
# first            NaN          NaN         NaN                NaN
# last             NaN          NaN         NaN                NaN
# mean    3.817489e+00          NaN         NaN                NaN
# std     2.018194e+00          NaN         NaN                NaN
# min     1.000000e+00          NaN         NaN                NaN
# 25%     2.000000e+00          NaN         NaN                NaN
# 50%     4.000000e+00          NaN         NaN                NaN
# 75%     6.000000e+00          NaN         NaN                NaN
# max     7.000000e+00          NaN         NaN                NaN
#
#         partnerSellingMonths  cancellationDays  shipmentDays  \
# count           4.772950e+06      77473.000000  4.695498e+06
# unique                   NaN               NaN           NaN
# top                      NaN               NaN           NaN
# freq                     NaN               NaN           NaN
# first                    NaN               NaN           NaN
# last                     NaN               NaN           NaN
# mean            5.222571e+01          1.786080  7.244867e-01
# std             2.776651e+01          4.950477  1.118229e+00
# min             0.000000e+00          0.000000  0.000000e+00
# 25%             3.000000e+01          0.000000  0.000000e+00
# 50%             5.100000e+01          1.000000  1.000000e+00
# 75%             7.500000e+01          2.000000  1.000000e+00
# max             1.640000e+02        479.000000  3.020000e+02
#
#         promisedDeliveryDays  actualDeliveryDays       caseDays  \
# count           4.772950e+06        3.067802e+06  164358.000000
# unique                   NaN                 NaN            NaN
# top                      NaN                 NaN            NaN
# freq                     NaN                 NaN            NaN
# first                    NaN                 NaN            NaN
# last                     NaN                 NaN            NaN
# mean            2.645849e+00        1.979201e+00       6.363019
# std             2.153588e+00        1.422276e+00       6.369027
# min             0.000000e+00        0.000000e+00       0.000000
# 25%             1.000000e+00        1.000000e+00       2.000000
# 50%             2.000000e+00        2.000000e+00       4.000000
# 75%             3.000000e+00        2.000000e+00       8.000000
# max             4.900000e+01        1.990000e+02      29.000000
#
#            returnDays countryCodeNL fulfilmentByBol countryOriginNL  \
# count   288763.000000       4772950         4772950         4772950
# unique            NaN             2               2               2
# top               NaN          True           False            True
# freq              NaN       3554065         3448479         4678541
# first             NaN           NaN             NaN             NaN
# last              NaN           NaN             NaN             NaN
# mean         8.247012           NaN             NaN             NaN
# std         16.425339           NaN             NaN             NaN
# min          0.000000           NaN             NaN             NaN
# 25%          2.000000           NaN             NaN             NaN
# 50%          5.000000           NaN             NaN             NaN
# 75%          9.000000           NaN             NaN             NaN
# max        672.000000           NaN             NaN             NaN
#
#        countryOriginBE countryOriginDE orderMonday orderTuesday  \
# count          4772950         4772950     4772950      4772950
# unique               2               2           2            2
# top              False           False       False        False
# freq           4685080         4766411     3993709      4030163
# first              NaN             NaN         NaN          NaN
# last               NaN             NaN         NaN          NaN
# mean               NaN             NaN         NaN          NaN
# std                NaN             NaN         NaN          NaN
# min                NaN             NaN         NaN          NaN
# 25%                NaN             NaN         NaN          NaN
# 50%                NaN             NaN         NaN          NaN
# 75%                NaN             NaN         NaN          NaN
# max                NaN             NaN         NaN          NaN
#
#        orderWednesday orderThursday orderFriday orderSaturday orderSunday  \
# count         4772950       4772950     4772950       4772950     4772950
# unique              2             2           2             2           2
# top             False         False       False         False       False
# freq          4015269       4098367     4162763       4247211     4090218
# first             NaN           NaN         NaN           NaN         NaN
# last              NaN           NaN         NaN           NaN         NaN
# mean              NaN           NaN         NaN           NaN         NaN
# std               NaN           NaN         NaN           NaN         NaN
# min               NaN           NaN         NaN           NaN         NaN
# 25%               NaN           NaN         NaN           NaN         NaN
# 50%               NaN           NaN         NaN           NaN         NaN
# 75%               NaN           NaN         NaN           NaN         NaN
# max               NaN           NaN         NaN           NaN         NaN
#
#        orderJanuary orderFebruary orderMarch orderApril orderMay orderJune  \
# count       4772950       4772950    4772950    4772950  4772950   4772950
# unique            2             2          2          2        2         2
# top           False         False      False      False    False     False
# freq        4443781       4489119    4410853    4377612  4381522   4393845
# first           NaN           NaN        NaN        NaN      NaN       NaN
# last            NaN           NaN        NaN        NaN      NaN       NaN
# mean            NaN           NaN        NaN        NaN      NaN       NaN
# std             NaN           NaN        NaN        NaN      NaN       NaN
# min             NaN           NaN        NaN        NaN      NaN       NaN
# 25%             NaN           NaN        NaN        NaN      NaN       NaN
# 50%             NaN           NaN        NaN        NaN      NaN       NaN
# 75%             NaN           NaN        NaN        NaN      NaN       NaN
# max             NaN           NaN        NaN        NaN      NaN       NaN
#
#        orderJuly orderAugust orderSeptember orderOctober orderNovember  \
# count    4772950     4772950        4772950      4772950       4772950
# unique         2           2              2            2             2
# top        False       False          False        False         False
# freq     4393771     4393696        4415844      4362460       4166185
# first        NaN         NaN            NaN          NaN           NaN
# last         NaN         NaN            NaN          NaN           NaN
# mean         NaN         NaN            NaN          NaN           NaN
# std          NaN         NaN            NaN          NaN           NaN
# min          NaN         NaN            NaN          NaN           NaN
# 25%          NaN         NaN            NaN          NaN           NaN
# 50%          NaN         NaN            NaN          NaN           NaN
# 75%          NaN         NaN            NaN          NaN           NaN
# max          NaN         NaN            NaN          NaN           NaN
#
#        orderDecember  productTitleLength
# count        4772950        4.772950e+06
# unique             2                 NaN
# top            False                 NaN
# freq         4273762                 NaN
# first            NaN                 NaN
# last             NaN                 NaN
# mean             NaN        6.092556e+01
# std              NaN        3.578114e+01
# min              NaN        1.000000e+00
# 25%              NaN        3.800000e+01
# 50%              NaN        5.300000e+01
# 75%              NaN        7.300000e+01
# max              NaN        3.230000e+02

# %%
#Calculate totals per Match Determinant
totalCase = df['caseDays'].count()
totalReturn = df['returnDays'].count()
totalCancel = df['cancellationDays'].count()
totalPromisedDelivery = df['promisedDeliveryDays'].count()
totalDelivery = df['actualDeliveryDays'].count()

# %%
#Create table for plot
periodTable = pd.concat([df['caseDays'].value_counts().sort_index(),
                         df['returnDays'].value_counts().sort_index(),
                         df['cancellationDays'].value_counts().sort_index(),
                         df['actualDeliveryDays'].value_counts().sort_index()],axis=1)

# %%
#Create percantages per day and calculate running sum
periodTable['caseDays%'] = (periodTable['caseDays'] / totalCase).cumsum()
periodTable['returnDays%'] = (periodTable['returnDays'] / totalReturn).cumsum()
periodTable['cancellationDays%'] = (periodTable['cancellationDays'] / totalCancel).cumsum()
periodTable['actualDeliveryDays%'] = (periodTable['actualDeliveryDays'] / df.shape[0]).cumsum()

# %%
### Plot parameters
plt.rcParams.update({'font.size': 18})

# Turn interactive plotting off
plt.ioff()

# Color palettes
color1 = ['#364958','#3b6064','#55828b','#87bba2','#c9e4ca']
color2 = ['#051923','#003554','#006494','#0582ca','#00a6fb']
color3 = ['#fb8500','#ffb703','#023047','#219ebc','#8ecae6']
color4 = ['#0e1236','#21538e','#92bdd8','#99c244','#54c244']
COLOR = color4

### Plotten
plt.figure(figsize = (17,9))

plt.plot(periodTable['caseDays%'], color=COLOR[0], marker = 'o', linewidth=3)
plt.plot(periodTable['returnDays%'], color=COLOR[1], marker = 'o', linewidth=3)
plt.plot(periodTable['cancellationDays%'], color=COLOR[2], marker = 'o', linewidth=3)
plt.plot(periodTable['actualDeliveryDays%'], color=COLOR[4], marker = 'o', linewidth=3)

### Titel
plt.title('', fontweight = 'bold')

### Assen
plt.ylabel('% Available', fontweight = 'bold')
plt.ylim(0,1.0)

plt.xlabel('Days after order', fontweight = 'bold')
plt.xlim(-0.1, 30.1)
#plt.xticks(x,('tick_1', 'tick_2', 'tick_3', 'tick_4'))

#plt.axvline(x=5, color='red')

### Grafiek Lay-out
plt.grid(color='#C0C0C0', linestyle='-', linewidth=1, axis = 'y')
plt.legend(('Case', 'Return', 'Cancel', 'Delivery'),loc='lower right')
plt.tick_params(direction='out', length=0, colors='black')
sns.despine(left=False, bottom=False, right=True)

plt.savefig('plot.png',dpi = 300)
plt.show()

# %%
def createColumns(df,X):
    """
    Function to create dynamic columns based on the prediction period.
    X = number of days after order date
    """
    
    dynamic_cols = ['caseDays','returnDays','cancellationDays','actualDeliveryDays']
    
    for col in dynamic_cols:
        
        dynamic_colname = col+'_'+str(X)
        df[dynamic_colname] = df[col].dt.days
        df[dynamic_colname] = df[dynamic_colname].apply(lambda x: x if x <= X else None)
        
    return df

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
#Categorical variables
s = (df.dtypes == 'object')
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
# Out:
# Categorical variables:
# ['productId', 'sellerId', 'countryCode', 'cancellationReasonCode', 'transporterCode', 'transporterName', 'transporterNameOther', 'fulfilmentType', 'returnCode', 'productTitle', 'brickName', 'chunkName', 'productGroup', 'productSubGroup', 'productSubSubGroup', 'countryOriginSeller', 'currentCountryAvailabilitySeller', 'onTimeDelivery', 'detailedMatchClassification', 'generalMatchClassification', 'determinantClassification', 'orderMonth', 'orderYearMonth', 'transporterFeature']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

clf = DecisionTreeClassifier(random_state=0,
                             class_weight='balanced')

X = ['totalPrice','quantityOrdered','promisedDeliveryDays','orderCorona','partnerSellingMonths',
        'countryCodeNL', 'fulfilmentByBol', 'countryOriginNL', 'countryOriginBE', 'countryOriginDE', 'orderWeekend',
        'orderMonday','orderTuesday', 'orderWednesday', 'orderThursday', 'orderFriday', 'orderSaturday', 'orderSunday',
        'orderJanuary', 'orderFebruary', 'orderMarch', 'orderApril', 'orderMay', 'orderJune', 'orderJuly',
        'orderAugust', 'orderSeptember', 'orderOctober', 'orderNovember', 'orderDecember', 'productTitleLength']
y = ['generalMatchClassification']
    
df_test = df[X+y].dropna()

clf = clf.fit(df_test[X],df_test[y])

prediction = clf.predict(df_test[X])

print("Accuracy:",metrics.accuracy_score(df_test[y], prediction))
# Out:
# Accuracy: 0.9141690149697776

# %%
from sklearn import tree
text_representation = tree.export_text(clf)
print(text_representation)

# %%
plt.rcParams.update({'font.size': 8})
importanceDF = pd.DataFrame(clf.feature_importances_,index=X,columns=['importance']).sort_values('importance',ascending=False)
importanceDF.plot.bar(figsize=(4,4))
plt.show()

# %%
print(metrics.classification_report(df_test[y], prediction))
# Out:
#               precision    recall  f1-score   support
#
#  KNOWN HAPPY       0.98      0.90      0.94   2685606
#      UNHAPPY       0.63      0.90      0.74    569696
#      UNKNOWN       0.96      0.94      0.95   1517648
#
#     accuracy                           0.91   4772950
#    macro avg       0.86      0.91      0.88   4772950
# weighted avg       0.93      0.91      0.92   4772950

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split

RF = RandomForestClassifier(n_estimators=10,
                            random_state=0,
                            class_weight='balanced')

X = ['totalPrice','quantityOrdered','promisedDeliveryDays','orderCorona','partnerSellingMonths',
        'countryCodeNL', 'fulfilmentByBol', 'countryOriginNL', 'countryOriginBE', 'countryOriginDE', 'orderWeekend',
        'orderMonday','orderTuesday', 'orderWednesday', 'orderThursday', 'orderFriday', 'orderSaturday', 'orderSunday',
        'orderJanuary', 'orderFebruary', 'orderMarch', 'orderApril', 'orderMay', 'orderJune', 'orderJuly',
        'orderAugust', 'orderSeptember', 'orderOctober', 'orderNovember', 'orderDecember', 'productTitleLength']
y = ['generalMatchClassification']

df_test = df[X+y].dropna()

RF_fit = RF.fit(df_test[X], df_test[y])
RF_pred = RF_fit.predict(df_test[X])

RF_acc = metrics.accuracy_score(df_test[y], RF_pred)
# Out:
# <ipython-input-81-333291ae0431>:19: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_fit = RF.fit(df_test[X], df_test[y])

# %%
RF_acc
# Out:
# 0.9152054808870824

# %%
# Random Forest Stratified Kfold

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold

kf = StratifiedKFold(n_splits = 3, random_state = 0, shuffle = True)

accuracy_K = {}
class_report_K = {}
count = 1

df_test = df[X+y].dropna()

X = ['totalPrice','quantityOrdered','promisedDeliveryDays','orderCorona','partnerSellingMonths',
        'countryCodeNL', 'fulfilmentByBol', 'countryOriginNL', 'countryOriginBE', 'countryOriginDE', 'orderWeekend',
        'orderMonday','orderTuesday', 'orderWednesday', 'orderThursday', 'orderFriday', 'orderSaturday', 'orderSunday',
        'orderJanuary', 'orderFebruary', 'orderMarch', 'orderApril', 'orderMay', 'orderJune', 'orderJuly',
        'orderAugust', 'orderSeptember', 'orderOctober', 'orderNovember', 'orderDecember', 'productTitleLength']
y = ['generalMatchClassification']

#kf.split(df_test[X], df_test[y])

for train_index, test_index in kf.split(df_test[X], df_test[y]):

    X_train, X_test = df_test[X].iloc[train_index], df_test[X].iloc[test_index]
    y_train, y_test = df_test[y].iloc[train_index], df_test[y].iloc[test_index]
    
    rfclf = RandomForestClassifier(n_estimators=10,
                            random_state=0,
                            class_weight='balanced')
    
    rfclf = rfclf.fit(X_train,y_train)

    prediction = rfclf.predict(X_test)
    
    accuracy_K[count] = metrics.accuracy_score(y_test, prediction)
    class_report_K[count] = metrics.classification_report(y_test, prediction)
    
    print(count)
    count +=1
# Out:
# <ipython-input-83-8652eb75d9f2>:34: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfclf = rfclf.fit(X_train,y_train)
# 1
# <ipython-input-83-8652eb75d9f2>:34: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfclf = rfclf.fit(X_train,y_train)
# 2
# <ipython-input-83-8652eb75d9f2>:34: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfclf = rfclf.fit(X_train,y_train)
# 3

# %%
for item in class_report_K.values():
    print(item)
# Out:
#               precision    recall  f1-score   support
#
#  KNOWN HAPPY       0.81      0.87      0.84    895202
#      UNHAPPY       0.22      0.16      0.18    189899
#      UNKNOWN       0.81      0.80      0.80    505883
#
#     accuracy                           0.76   1590984
#    macro avg       0.61      0.61      0.61   1590984
# weighted avg       0.74      0.76      0.75   1590984
#
#               precision    recall  f1-score   support
#
#  KNOWN HAPPY       0.82      0.87      0.84    895202
#      UNHAPPY       0.22      0.16      0.19    189898
#      UNKNOWN       0.81      0.80      0.81    505883
#
#     accuracy                           0.76   1590983
#    macro avg       0.62      0.61      0.61   1590983
# weighted avg       0.74      0.76      0.75   1590983
#
#               precision    recall  f1-score   support
#
#  KNOWN HAPPY       0.82      0.87      0.84    895202
#      UNHAPPY       0.22      0.16      0.19    189899
#      UNKNOWN       0.81      0.80      0.81    505882
#
#     accuracy                           0.76   1590983
#    macro avg       0.62      0.61      0.61   1590983
# weighted avg       0.74      0.76      0.75   1590983

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import KFold
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

index = ['orderDate']
X_col = ['totalPrice','quantityOrdered','promisedDeliveryDays','orderCorona','partnerSellingMonths',
        'countryCodeNL', 'fulfilmentByBol', 'countryOriginNL', 'countryOriginBE', 'countryOriginDE', 'orderWeekend',
        'orderMonday','orderTuesday', 'orderWednesday', 'orderThursday', 'orderFriday', 'orderSaturday', 'orderSunday',
        'orderJanuary', 'orderFebruary', 'orderMarch', 'orderApril', 'orderMay', 'orderJune', 'orderJuly',
        'orderAugust', 'orderSeptember', 'orderOctober', 'orderNovember', 'orderDecember', 'productTitleLength']
y_col = ['generalMatchClassification']

df_test = df[index+X_col+y_col].dropna()
df_test = df_test.sort_values(by = 'orderDate')
df_test = df_test.reset_index(drop = True)

X = df_test[X_col]
y = df_test[y_col]

# %%
#TIME-SERIES SPLIT

tscv = TimeSeriesSplit(n_splits = 3)

accuracy = {}
class_report = {}
count = 1

for train_index, test_index in tscv.split(X):

    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    clf = DecisionTreeClassifier(random_state=0,
                                 class_weight='balanced')
    
    clf = clf.fit(X_train,y_train)

    prediction = clf.predict(X_test)
    
    accuracy[count] = metrics.accuracy_score(y_test, prediction)
    class_report[count] = metrics.classification_report(y_test, prediction)
    
    print(count)
    count += 1
# Out:
# 1
# 2
# 3

# %%
for item in class_report.values():
    print(item)
# Out:
#               precision    recall  f1-score   support
#
#  KNOWN HAPPY       0.65      0.64      0.64    648698
#      UNHAPPY       0.13      0.19      0.16    148188
#      UNKNOWN       0.56      0.48      0.51    396351
#
#     accuracy                           0.53   1193237
#    macro avg       0.45      0.44      0.44   1193237
# weighted avg       0.55      0.53      0.54   1193237
#
#               precision    recall  f1-score   support
#
#  KNOWN HAPPY       0.68      0.63      0.66    724953
#      UNHAPPY       0.13      0.19      0.15    140996
#      UNKNOWN       0.44      0.43      0.43    327288
#
#     accuracy                           0.52   1193237
#    macro avg       0.42      0.42      0.41   1193237
# weighted avg       0.55      0.52      0.54   1193237
#
#               precision    recall  f1-score   support
#
#  KNOWN HAPPY       0.67      0.66      0.67    671437
#      UNHAPPY       0.12      0.18      0.15    137888
#      UNKNOWN       0.56      0.48      0.52    383912
#
#     accuracy                           0.55   1193237
#    macro avg       0.45      0.44      0.45   1193237
# weighted avg       0.57      0.55      0.56   1193237

# %%
#RANDOM KFOLD SPLIT

from sklearn.model_selection import StratifiedKFold

kf = StratifiedKFold(n_splits = 3, random_state = 0, shuffle = True)

accuracy_K = {}
class_report_K = {}
count = 1

for train_index, test_index in kf.split(X, y):

    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    clf = DecisionTreeClassifier(random_state=0,
                                 class_weight='balanced')
    
    clf = clf.fit(X_train,y_train)

    prediction = clf.predict(X_test)
    
    accuracy_K[count] = metrics.accuracy_score(y_test, prediction)
    class_report_K[count] = metrics.classification_report(y_test, prediction)
    
    print(count)
    count +=1
# Out:
# 1
# 2
# 3

# %%
for item in class_report_K.values():
    print(item)
# Out:
#               precision    recall  f1-score   support
#
#  KNOWN HAPPY       0.83      0.77      0.80    895202
#      UNHAPPY       0.19      0.25      0.22    189899
#      UNKNOWN       0.79      0.77      0.78    505883
#
#     accuracy                           0.71   1590984
#    macro avg       0.60      0.60      0.60   1590984
# weighted avg       0.74      0.71      0.72   1590984
#
#               precision    recall  f1-score   support
#
#  KNOWN HAPPY       0.83      0.77      0.80    895202
#      UNHAPPY       0.19      0.25      0.21    189898
#      UNKNOWN       0.78      0.77      0.78    505883
#
#     accuracy                           0.71   1590983
#    macro avg       0.60      0.60      0.60   1590983
# weighted avg       0.74      0.71      0.72   1590983
#
#               precision    recall  f1-score   support
#
#  KNOWN HAPPY       0.83      0.77      0.80    895202
#      UNHAPPY       0.19      0.25      0.21    189899
#      UNKNOWN       0.79      0.77      0.78    505882
#
#     accuracy                           0.71   1590983
#    macro avg       0.60      0.60      0.60   1590983
# weighted avg       0.74      0.71      0.72   1590983

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE('not majority')
X_sm, y_sm = smote.fit_sample(df_test[X],df_test[y])
print(df_test[X].shape, df_test[y].shape)
print(X_sm.shape, y_sm.shape)
# Out:
# C:\Users\thoma\Anaconda3\lib\site-packages\imblearn\utils\_validation.py:635: FutureWarning: Pass sampling_strategy=not majority as keyword args. From version 0.9 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.9 "
# (4772950, 31) (4772950, 1)
# (8056818, 31) (8056818, 1)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

clf = DecisionTreeClassifier(random_state=0,
                             class_weight='balanced')
    
(X_sm+y_sm).dropna()

clf = clf.fit(X_sm,y_sm)

prediction = clf.predict(X_sm)

print("Accuracy:",metrics.accuracy_score(y_sm, prediction))

# Check accuracy on original data samples
# Out:
# Accuracy: 0.9451319367025542

# %%
print(metrics.classification_report(y_sm, prediction))
# Out:
#               precision    recall  f1-score   support
#
#  KNOWN HAPPY       0.92      0.97      0.95   2685606
#      UNHAPPY       0.95      0.90      0.93   2685606
#      UNKNOWN       0.96      0.96      0.96   2685606
#
#     accuracy                           0.95   8056818
#    macro avg       0.95      0.95      0.94   8056818
# weighted avg       0.95      0.95      0.94   8056818

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE('not majority')
# Out:
# C:\Users\thoma\Anaconda3\lib\site-packages\imblearn\utils\_validation.py:635: FutureWarning: Pass sampling_strategy=not majority as keyword args. From version 0.9 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.9 "

# %%
#RANDOM SMOTE STRATIFIEDKFOLD SPLIT

from sklearn.model_selection import StratifiedKFold

kf = StratifiedKFold(n_splits = 3, random_state = 0, shuffle = True)

accuracy_K = {}
class_report_K = {}
count = 1

for train_index, test_index in kf.split(df_test[X], df_test[y]):

    X_train, X_test = df_test[X].iloc[train_index], df_test[X].iloc[test_index]
    y_train, y_test = df_test[y].iloc[train_index], df_test[y].iloc[test_index]
    
    X_train_sm, y_train_sm = smote.fit_sample(df_test[X],df_test[y])
    
    clf = DecisionTreeClassifier(random_state=0,
                                 class_weight='balanced')
    
    clf = clf.fit(X_train_sm,y_train_sm)

    prediction = clf.predict(X_test)
    
    accuracy_K[count] = metrics.accuracy_score(y_test, prediction)
    class_report_K[count] = metrics.classification_report(y_test, prediction)
    
    print(count)
    count +=1
# Out:
# 1
# 2
# 3

# %%
for item in class_report_K.values():
    print(item)
# Out:
#               precision    recall  f1-score   support
#
#  KNOWN HAPPY       0.94      0.97      0.96    895202
#      UNHAPPY       0.79      0.72      0.75    189899
#      UNKNOWN       0.96      0.94      0.95    505883
#
#     accuracy                           0.93   1590984
#    macro avg       0.90      0.88      0.89   1590984
# weighted avg       0.93      0.93      0.93   1590984
#
#               precision    recall  f1-score   support
#
#  KNOWN HAPPY       0.94      0.97      0.96    895202
#      UNHAPPY       0.79      0.72      0.75    189898
#      UNKNOWN       0.96      0.94      0.95    505883
#
#     accuracy                           0.93   1590983
#    macro avg       0.90      0.88      0.89   1590983
# weighted avg       0.93      0.93      0.93   1590983
#
#               precision    recall  f1-score   support
#
#  KNOWN HAPPY       0.94      0.97      0.96    895202
#      UNHAPPY       0.79      0.72      0.75    189899
#      UNKNOWN       0.96      0.94      0.95    505882
#
#     accuracy                           0.93   1590983
#    macro avg       0.90      0.88      0.89   1590983
# weighted avg       0.93      0.93      0.93   1590983

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE('not majority')
# Out:
# C:\Users\thoma\Anaconda3\lib\site-packages\imblearn\utils\_validation.py:635: FutureWarning: Pass sampling_strategy=not majority as keyword args. From version 0.9 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.9 "

# %%
#TIME-SERIES SPLIT

tscv = TimeSeriesSplit(n_splits = 3)

accuracy = {}
class_report = {}
count = 1

for train_index, test_index in tscv.split(df_test[X]):

    X_train, X_test = df_test[X].iloc[train_index], df_test[X].iloc[test_index]
    y_train, y_test = df_test[y].iloc[train_index], df_test[y].iloc[test_index]
    
    X_train_sm, y_train_sm = smote.fit_sample(df_test[X_train],df_test[y_train])
    
    clf = DecisionTreeClassifier(random_state=0,
                                 class_weight='balanced')
    
    clf = clf.fit(X_train_sm,y_train_sm)

    prediction = clf.predict(X_test)
    
    accuracy[count] = metrics.accuracy_score(y_test, prediction)
    class_report[count] = metrics.classification_report(y_test, prediction)
    
    print(count)
    count += 1

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y
